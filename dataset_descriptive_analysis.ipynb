# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

FILE_TEST = 'formatted_csv_dataset/formatted_test.tweet.csv'
FILE_TRAIN = 'formatted_csv_dataset/formatted_training.csv'

tweets_df_base = pd.read_csv(FILE_TRAIN, sep=',')

# Swap latitude and longitude column values; we made a mistake when formatting the dataset to a csv file
tweets_df_base.rename(columns={'coordinates_lat' : 'coordinates_lat_old'}, inplace=True)
tweets_df_base.rename(columns={'coordinates_long' : 'coordinates_lat'}, inplace=True)
tweets_df_base.rename(columns={'coordinates_lat_old' : 'coordinates_long'}, inplace=True)

test_tweets_df_base = pd.read_csv(FILE_TEST, sep=',')

# %%
from matplotlib import rc

rc('font', size=15)

print('Plotting training and test sets scatter plots')

fig = plt.figure(figsize=(7, 12))

fig = plt.subplot(211)
plt.scatter(tweets_df_base['coordinates_long'], tweets_df_base['coordinates_lat'])
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Training dataset')

fig = plt.subplot(212)
plt.scatter(test_tweets_df_base['coordinates_long'], test_tweets_df_base['coordinates_lat'])
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Test dataset')

plt.show()
# Out:
# Plotting training and test sets scatter plots

# %%
tweets_df_base.head(1)
# Out:
#                        created_at                  id lang  retweeted  \
# 0  Thu Sep 05 19:02:04 +0000 2013  375695343696236544   es      False
#
#    retweet_count place                       text  user_id_str  \
# 0              0   NaN  @hcorbacho Exactamente!!!    172417422
#
#               user_name user_screen_name  ...  \
# 0  Daphne Corral 💪 #24A       barzadafne  ...
#
#                                     user_description user_followers_count  \
# 0  Necesitas traducir textos, videos, folletos, a...                 3900
#
#    user_friends_count                 user_created_at user_geo_enabled  \
# 0                3272  Thu Jul 29 17:25:38 +0000 2010             True
#
#    user_verified  user_lang  coordinates_long  coordinates_lat   tweet_city
# 0          False        NaN         -58.63203        -34.48449  moron-01-ar
#
# [1 rows x 21 columns]

# %%
from collections import Counter

user_counts_train = list()
for val, df in tweets_df_base.groupby('user_screen_name'):
    user_counts_train.append(df.shape[0])

user_counter_train = Counter(user_counts_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-f06a4db05686> in <module>
#       2
#       3 user_counts_train = list()
# ----> 4 for val, df in tweets_df_base.groupby('user_screen_name'):
#       5     user_counts_train.append(df.shape[0])
#       6
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in get_iterator(self, data, axis)
#     143         splitter = self._get_splitter(data, axis=axis)
#     144         keys = self._get_group_keys()
# --> 145         for key, (i, group) in zip(keys, splitter):
#     146             yield key, group
#     147
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in __iter__(self)
#     826             #     raise AssertionError('Start %s must be less than end %s'
#     827             #                          % (str(start), str(end)))
# --> 828             yield i, self._chop(sdata, slice(start, end))
#     829
#     830     def _get_sorted_data(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _chop(self, sdata, slice_obj)
#     862     def _chop(self, sdata, slice_obj):
#     863         if self.axis == 0:
# --> 864             return sdata.iloc[slice_obj]
#     865         else:
#     866             return sdata._slice(slice_obj, axis=1)  # .loc[:, slice_obj]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2208
#    2209         if isinstance(key, slice):
# -> 2210             return self._get_slice_axis(key, axis=axis)
#    2211
#    2212         if isinstance(key, list):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2178         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2179         if isinstance(slice_obj, slice):
# -> 2180             return self._slice(slice_obj, axis=axis, kind='iloc')
#    2181         else:
#    2182             return self.obj._take(slice_obj, axis=axis)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _slice(self, obj, axis, kind)
#     149         if axis is None:
#     150             axis = self.axis
# --> 151         return self.obj._slice(obj, axis=axis, kind=kind)
#     152
#     153     def _get_setitem_indexer(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _slice(self, slobj, axis, kind)
#    3160         """
#    3161         axis = self._get_block_manager_axis(axis)
# -> 3162         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    3163         result = result.__finalize__(self)
#    3164
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in get_slice(self, slobj, axis)
#     695
#     696         new_axes = list(self.axes)
# --> 697         new_axes[axis] = new_axes[axis][slobj]
#     698
#     699         bm = self.__class__(new_blocks, new_axes, do_integrity_check=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3961             # This case is separated from the conditional above to avoid
#    3962             # pessimization of basic indexing.
# -> 3963             return promote(getitem(key))
#    3964
#    3965         if com.is_bool_indexer(key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/numeric.py in _shallow_copy(self, values, **kwargs)
#      69         if values is not None and not self._can_hold_na:
#      70             # Ensure we are not returning an Int64Index with float data:
# ---> 71             return self._shallow_copy_with_infer(values=values, **kwargs)
#      72         return (super(NumericIndex, self)._shallow_copy(values=values,
#      73                                                         **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _shallow_copy_with_infer(self, values, **kwargs)
#     605             except (TypeError, ValueError):
#     606                 pass
# --> 607         return Index(values, **attributes)
#     608
#     609     def _update_inplace(self, result, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     264                 return cls._simple_new(data, name)
#     265
# --> 266         from .range import RangeIndex
#     267         if isinstance(data, ABCPandasArray):
#     268             # ensure users don't accidentally put a PandasArray in an index.
#
# ~/anaconda3/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
plt.bar([i for i in range(20)], [user_counter_train[i] for i in range(20)])
plt.xlabel('number of tweets')
plt.ylabel('number of users')
# Out:
# Text(0, 0.5, 'number of users')

# %%
from nltk.tokenize import word_tokenize

tweets_df_base['num_tokens'] = tweets_df_base['text'].apply(lambda t: len(word_tokenize(t.strip())) if type(t) == str else 0)
tweets_df_base['num_chars'] = tweets_df_base['text'].apply(lambda t: len(t.strip()) if type(t) == str else 0)

tweets_df_base.head(1)
# Out:
#                        created_at                  id lang  retweeted  \
# 0  Thu Sep 05 19:02:04 +0000 2013  375695343696236544   es      False
#
#    retweet_count place                       text  user_id_str  \
# 0              0   NaN  @hcorbacho Exactamente!!!    172417422
#
#               user_name user_screen_name  ... user_friends_count  \
# 0  Daphne Corral 💪 #24A       barzadafne  ...               3272
#
#                   user_created_at  user_geo_enabled  user_verified user_lang  \
# 0  Thu Jul 29 17:25:38 +0000 2010              True          False       NaN
#
#    coordinates_long  coordinates_lat   tweet_city  num_tokens  num_chars
# 0         -58.63203        -34.48449  moron-01-ar           6         25
#
# [1 rows x 23 columns]

# %%
tokens_count = list()
for val, df in tweets_df_base.groupby('num_tokens'):
    tokens_count.append((val, df.shape[0]))
    
chars_count = list()
for val, df in tweets_df_base.groupby('num_chars'):
    chars_count.append((val, df.shape[0]))
# Out:
# Text(0.5, 1.0, 'Distribution of number of characters across tweets')

# %%
fig = plt.figure(figsize=(7, 12))

fig = plt.subplot(211)
plt.bar([num_tokens for (num_tokens, count) in tokens_count[:50]], [count for (num_tokens, count) in tokens_count[:50]])
plt.xlabel('number of tokens')
plt.ylabel('number of tweets')
plt.title('Distribution of number of tokens across tweets')


fig = plt.subplot(212)
plt.bar([num_chars for (num_chars, count) in chars_count[:150]], [count for (num_chars, count) in chars_count[:150]])
plt.xlabel('number of characters')
plt.ylabel('number of tweets')
# plt.xticks(rotation=90)
plt.title('Distribution of number of characters across tweets')
# Out:
# Text(0.5, 1.0, 'Distribution of number of characters across tweets')

# %%
print('user_geo_enabled')
for val, df in tweets_df_base.groupby('user_geo_enabled'):
    print((val, df.shape[0] / tweets_df_base.shape[0] * 100))
    
print('\nuser_verified')
for val, df in tweets_df_base.groupby('user_verified'):
    print((val, df.shape[0] / tweets_df_base.shape[0] * 100))
# Out:
# user_geo_enabled
# (False, 2.970493671186557)
# (True, 97.02950632881344)
#
# user_verified
# (False, 99.50340112729104)
# (True, 0.4965988727089537)

# %%
print('num_users: ', tweets_df_base['user_screen_name'].unique().shape[0])
# Out:
# num_users:  632474

# %%
city_count = list()
for val, df in tweets_df_base.groupby('tweet_city'):
    city_count.append((val, df.shape[0]))

city_count = sorted(city_count, key=lambda c: c[1], reverse=True)
city_cdf = pd.Series([count for (city, count) in city_count]).cumsum()

print(len(city_count), ' cities')
# Out:
# 3262  cities

# %%
fig = plt.figure(figsize=(7, 12))

fig = plt.subplot(211)
plt.plot([i for i in range(len(city_count))], [count for (city, count) in city_count])
plt.xlabel('city')
plt.ylabel('number of tweets')
# plt.xticks(rotation=90)
plt.title('Distribution of tweets across cities')

fig = plt.subplot(212)
plt.plot([i for i in range(len(city_count))], city_cdf)
plt.xlabel('city')
plt.ylabel('number of tweets')
# plt.xticks(rotation=90)
plt.title('Cumulative sum of tweets across cities')
# Out:
# Text(0.5, 1.0, 'Cumulative sum of tweets across cities')

# %%
# Least frequent cities
print('Cities with 1 tweet: ', len([city for (city, count) in city_count if count == 1]))


# Most frequent cities 
top_1k = sum([count for (city, count) in city_count[:1000]])
top_100 = sum([count for (city, count) in city_count[:100]])
total = sum([count for (city, count) in city_count]) 

top_1k / total , top_100 / total
# Out:
# Cities with 1 tweet:  110
# (0.9438544966357985, 0.40115287533068344)

# %%
lang_count = list()
for val, df in tweets_df_base.groupby('lang'):
    lang_count.append((val, df.shape[0]))

print(len(lang_count), ' languages')

sorted(lang_count, key=lambda l: l[1], reverse=True)
# Out:
# 39  languages
# [('en', 6077189),
#  ('und', 472248),
#  ('in', 384934),
#  ('pt', 131473),
#  ('es', 130879),
#  ('tl', 104066),
#  ('fr', 44726),
#  ('tr', 40557),
#  ('et', 28430),
#  ('ht', 24685),
#  ('nl', 19903),
#  ('it', 19861),
#  ('ca', 13314),
#  ('de', 10345),
#  ('pl', 9366),
#  ('da', 7613),
#  ('lv', 7281),
#  ('hi', 7120),
#  ('sv', 6846),
#  ('eu', 6728),
#  ('cy', 6557),
#  ('no', 5670),
#  ('ro', 5003),
#  ('lt', 3981),
#  ('cs', 3686),
#  ('hu', 2909),
#  ('fi', 2769),
#  ('is', 1840),
#  ('vi', 1174),
#  ('sl', 1138),
#  ('iw', 145),
#  ('ru', 125),
#  ('ja', 79),
#  ('ar', 47),
#  ('th', 41),
#  ('ko', 33),
#  ('zh', 15),
#  ('el', 3),
#  ('ka', 1)]
